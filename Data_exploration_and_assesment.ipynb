# %% [markdown]
# # Data exploration and assessment

# %% [markdown]
# ## Airport data

# %%
import pandas as pd

airports_file = 'airport-codes_csv.csv'
airports_df = pd.read_csv(airports_file)

print(airports_df.shape)
# Out:
# (55075, 12)

# %%
# pandas interprets continent = NA (North America) as nulls
# we manually add these back in for this stage, but note that it will not be necessary in the ETL pipeline as PySpark 
# does not make the same mistake
airports_df.loc[airports_df['continent'].isna(), 'continent'] = 'NA'
airports_df.isna().sum()/airports_df.shape[0]
# Out:
# ident           0.000000
# type            0.000000
# name            0.000000
# elevation_ft    0.127208
# continent       0.000000
# iso_country     0.004485
# iso_region      0.000000
# municipality    0.103059
# gps_code        0.255016
# iata_code       0.833155
# local_code      0.479147
# coordinates     0.000000
# dtype: float64

# %% [markdown]
# #### Around 83% of entries have no iata_code value. This will be an intesive task to update without providing much value. We will drop this column. In addition, we will not need to include gps_code or local_code, so these will also be removed.

# %%
# the iso_region column contains the US state code
# we will have to manuualy extract the two-letter code from the column
airports_df = airports_df.replace({'US-': ''}, regex=True)
airports_df.head()
# Out:
#   ident           type                                name  elevation_ft  \
# 0   00A       heliport                   Total Rf Heliport          11.0
# 1  00AA  small_airport                Aero B Ranch Airport        3435.0
# 2  00AK  small_airport                        Lowell Field         450.0
# 3  00AL  small_airport                        Epps Airpark         820.0
# 4  00AR         closed  Newport Hospital & Clinic Heliport         237.0
#
#   continent iso_country iso_region  municipality gps_code iata_code  \
# 0        NA          US         PA      Bensalem      00A       NaN
# 1        NA          US         KS         Leoti     00AA       NaN
# 2        NA          US         AK  Anchor Point     00AK       NaN
# 3        NA          US         AL       Harvest     00AL       NaN
# 4        NA          US         AR       Newport      NaN       NaN
#
#   local_code                            coordinates
# 0        00A     -74.93360137939453, 40.07080078125
# 1       00AA                 -101.473911, 38.704022
# 2       00AK            -151.695999146, 59.94919968
# 3       00AL  -86.77030181884766, 34.86479949951172
# 4        NaN                    -91.254898, 35.6087

# %% [markdown]
# ## US cities demographics data

# %%
demographics_file = 'us-cities-demographics.csv'
demo_df = pd.read_csv(demographics_file, delimiter=';')

print(demo_df.shape)
# Out:
# (2891, 12)

# %% [markdown]
# #### There are only 16 rows with any nulls, covering 8 cities, all of which are for relatively small. We disclude these.

# %%
demo_df[demo_df.isna().any(axis=1)]
# Out:
#               City        State  Median Age  Male Population  \
# 111       San Juan  Puerto Rico        41.4         155408.0
# 155         Caguas  Puerto Rico        40.4          34743.0
# 258       Carolina  Puerto Rico        42.0          64758.0
# 333   The Villages      Florida        70.5              NaN
# 449   The Villages      Florida        70.5              NaN
# 637       Carolina  Puerto Rico        42.0          64758.0
# 1437  The Villages      Florida        70.5              NaN
# 1747      San Juan  Puerto Rico        41.4         155408.0
# 1748      Mayagüez  Puerto Rico        38.1          30799.0
# 1995         Ponce  Puerto Rico        40.5          56968.0
# 2004       Bayamón  Puerto Rico        39.4          80128.0
# 2441      San Juan  Puerto Rico        41.4         155408.0
# 2589      Guaynabo  Puerto Rico        42.2          33066.0
# 2597        Caguas  Puerto Rico        40.4          34743.0
# 2654      Guaynabo  Puerto Rico        42.2          33066.0
# 2746      Mayagüez  Puerto Rico        38.1          30799.0
#
#       Female Population  Total Population  Number of Veterans  Foreign-born  \
# 111            186829.0            342237                 NaN           NaN
# 155             42265.0             77008                 NaN           NaN
# 258             77308.0            142066                 NaN           NaN
# 333                 NaN             72590             15231.0        4034.0
# 449                 NaN             72590             15231.0        4034.0
# 637             77308.0            142066                 NaN           NaN
# 1437                NaN             72590             15231.0        4034.0
# 1747           186829.0            342237                 NaN           NaN
# 1748            35782.0             66581                 NaN           NaN
# 1995            64615.0            121583                 NaN           NaN
# 2004            90131.0            170259                 NaN           NaN
# 2441           186829.0            342237                 NaN           NaN
# 2589            37426.0             70492                 NaN           NaN
# 2597            42265.0             77008                 NaN           NaN
# 2654            37426.0             70492                 NaN           NaN
# 2746            35782.0             66581                 NaN           NaN
#
#       Average Household Size State Code                               Race  \
# 111                      NaN         PR                 Hispanic or Latino
# 155                      NaN         PR                 Hispanic or Latino
# 258                      NaN         PR  American Indian and Alaska Native
# 333                      NaN         FL                 Hispanic or Latino
# 449                      NaN         FL          Black or African-American
# 637                      NaN         PR                 Hispanic or Latino
# 1437                     NaN         FL                              White
# 1747                     NaN         PR  American Indian and Alaska Native
# 1748                     NaN         PR                              Asian
# 1995                     NaN         PR                 Hispanic or Latino
# 2004                     NaN         PR                 Hispanic or Latino
# 2441                     NaN         PR                              Asian
# 2589                     NaN         PR                 Hispanic or Latino
# 2597                     NaN         PR  American Indian and Alaska Native
# 2654                     NaN         PR  American Indian and Alaska Native
# 2746                     NaN         PR                 Hispanic or Latino
#
#        Count
# 111   335559
# 155    76349
# 258    12143
# 333     1066
# 449      331
# 637   139967
# 1437   72211
# 1747    4031
# 1748     235
# 1995  120705
# 2004  169155
# 2441    2452
# 2589   69936
# 2597     624
# 2654     589
# 2746   65521

# %% [markdown]
# #### Each city has counts for between 1 and 5 races, which creates duplicate rows. For around 79% of the rows, all but two of the columns (Race and Count) are redundant. We'll create a new table which contains the race data, and remove it from the demographics table to reduce storage space required.

# %%
min_races = min(demo_df.groupby(['City', 'State']).size())
max_races = max(demo_df.groupby(['City', 'State']).size())
print(min_races, max_races)
# Out:
# 1 5

# %%
# Proportion of duplicated rows when Race and Count columns are removed
1-demo_df[['City', 'State']].drop_duplicates().shape[0]/demo_df.shape[0]
# Out:
# 0.7938429609131789

# %% [markdown]
# ## Temperature data

# %%
temperature_file = '../../data2/GlobalLandTemperaturesByCity.csv'
temp_df = pd.read_csv(temperature_file)

temp_df.head()
# Out:
#            dt  AverageTemperature  AverageTemperatureUncertainty   City  \
# 0  1743-11-01               6.068                          1.737  Århus
# 1  1743-12-01                 NaN                            NaN  Århus
# 2  1744-01-01                 NaN                            NaN  Århus
# 3  1744-02-01                 NaN                            NaN  Århus
# 4  1744-03-01                 NaN                            NaN  Århus
#
#    Country Latitude Longitude
# 0  Denmark   57.05N    10.33E
# 1  Denmark   57.05N    10.33E
# 2  Denmark   57.05N    10.33E
# 3  Denmark   57.05N    10.33E
# 4  Denmark   57.05N    10.33E
#                dt  AverageTemperature  AverageTemperatureUncertainty     City  \
# 47555  1820-01-01               2.101                          3.217  Abilene
# 47556  1820-02-01               6.926                          2.853  Abilene
# 47557  1820-03-01              10.767                          2.395  Abilene
# 47558  1820-04-01              17.989                          2.202  Abilene
# 47559  1820-05-01              21.809                          2.036  Abilene
#
#              Country Latitude Longitude
# 47555  United States   32.95N   100.53W
# 47556  United States   32.95N   100.53W
# 47557  United States   32.95N   100.53W
# 47558  United States   32.95N   100.53W
# 47559  United States   32.95N   100.53W

# %%
print(min(temp_df['dt']), max(temp_df['dt']))
# Out:
# 1743-11-01 2013-09-01

# %% [markdown]
# #### The temperature data we have covers 1743 to 2013, while the immigration dataset covers 2016 only. As there is no date overlap between these two, we cannot join on date. We instead take the latest 10 year's of temperature for each city going forward, averaged for each month.

# %%
temp_df['dt'] = pd.to_datetime(temp_df['dt'], format='%Y/%m/%d')

# %%
temp_10_years_df = temp_df[temp_df['dt'] >= max(temp_df['dt']) - pd.offsets.DateOffset(years=10)]

# %%
temp_10_years_df['month'] = pd.DatetimeIndex(temp_10_years_df['dt']).month

temp_10_years_df.head()
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#              dt  AverageTemperature  AverageTemperatureUncertainty   City  \
# 3118 2003-09-01              14.425                          0.172  Århus
# 3119 2003-10-01               6.621                          0.467  Århus
# 3120 2003-11-01               6.016                          0.295  Århus
# 3121 2003-12-01               3.697                          0.284  Århus
# 3122 2004-01-01              -0.660                          0.204  Århus
#
#       Country Latitude Longitude  month
# 3118  Denmark   57.05N    10.33E      9
# 3119  Denmark   57.05N    10.33E     10
# 3120  Denmark   57.05N    10.33E     11
# 3121  Denmark   57.05N    10.33E     12
# 3122  Denmark   57.05N    10.33E      1

# %%
temp_10_years_df.groupby(['City','Country','Latitude','Longitude','month']).mean().reset_index()
# Out:
#            City     Country Latitude Longitude  month  AverageTemperature  \
# 0      A Coruña       Spain   42.59N     8.73W      1              9.1581
# 1      A Coruña       Spain   42.59N     8.73W      2              9.2842
# 2      A Coruña       Spain   42.59N     8.73W      3             11.2129
# 3      A Coruña       Spain   42.59N     8.73W      4             12.6073
# 4      A Coruña       Spain   42.59N     8.73W      5             14.8401
# 5      A Coruña       Spain   42.59N     8.73W      6             17.8176
# 6      A Coruña       Spain   42.59N     8.73W      7             19.1891
# 7      A Coruña       Spain   42.59N     8.73W      8             19.5752
# 8      A Coruña       Spain   42.59N     8.73W      9             18.4079
# 9      A Coruña       Spain   42.59N     8.73W     10             15.2289
# 10     A Coruña       Spain   42.59N     8.73W     11             11.5217
# 11     A Coruña       Spain   42.59N     8.73W     12              9.2684
# 12       Aachen     Germany   50.63N     6.34E      1              1.8348
# 42117    Ürümqi       China   44.20N    87.20E     10              8.6536
# 42118    Ürümqi       China   44.20N    87.20E     11             -1.1691
# 42119    Ürümqi       China   44.20N    87.20E     12            -11.2753
#
#        AverageTemperatureUncertainty
# 0                             0.3537
# 1                             0.3760
# 2                             0.3913
# 3                             0.4009
# 4                             0.3503
# 5                             0.4524
# 6                             0.6247
# 7                             0.4898
# 8                             0.4114
# 9                             0.4015
# 10                            0.4195
# 11                            0.3439
# 12                            0.2197
# 13                            0.1949
# 14                            0.2120
# 15                            0.2126
# 16                            0.2305
# 17                            0.2433
# 18                            0.2257
# 19                            0.2339
# 20                            0.2115
# 21                            0.1853
# 22                            0.2147
# 23                            0.2371
# 24                            0.3363
# 25                            0.2787
# 26                            0.3545
# 27                            0.3088
# 28                            0.2901
# 29                            0.2937
# ...                              ...
# 42090                         0.4171
# 42091                         0.4051
# 42092                         0.4437
# 42093                         0.3095
# 42094                         0.4381
# 42095                         0.3940
# 42096                         0.6564
# 42097                         0.7909
# 42098                         0.5531
# 42099                         0.3700
# 42100                         0.3765
# 42101                         0.3967
# 42102                         0.4242
# 42103                         0.4163
# 42104                         0.3617
# 42105                         0.3526
# 42106                         0.4359
# 42107                         0.8837
# 42108                         0.9199
# 42109                         1.0192
# 42110                         1.0328
# 42111                         0.4970
# 42112                         0.4596
# 42113                         0.3792
# 42114                         0.4092
# 42115                         0.4670
# 42116                         0.3792
# 42117                         0.5854
# 42118                         0.6036
# 42119                         0.9781
#
# [42120 rows x 7 columns]

# %% [markdown]
# ## Immigration data

# %%
fname = '../../data/18-83510-I94-Data-2016/i94_jan16_sub.sas7bdat'
df = pd.read_sas(fname, 'sas7bdat', encoding="ISO-8859-1")

df.head()
# Out:
# (2847924, 28) (3742, 28)

# %% [markdown]
# #### Some columns in the immigrant data table are mostly (>95%) nulls, including 'occup', 'entdepu', and 'insnum'. We will disclude these

# %%
df.isna().sum()/df.shape[0]*100
# Out:
# cicid        0.000000
# i94yr        0.000000
# i94mon       0.000000
# i94cit       0.000000
# i94res       0.000000
# i94port      0.000000
# arrdate      0.000000
# i94mode      0.004941
# i94addr      5.171279
# depdate      4.414819
# i94bir       0.028001
# i94visa      0.000000
# count        0.000000
# dtadfile     0.000063
# visapost    60.509611
# occup       99.556836
# entdepa      0.004878
# entdepd      4.333889
# entdepu     99.988122
# matflag      4.333889
# biryear      0.028001
# dtaddto      0.018340
# gender      11.824817
# insnum      95.661360
# airline      3.217317
# admnum       0.000000
# fltno        0.388841
# visatype     0.000000
# dtype: float64

# %%
df.drop(['occup', 'entdepu', 'insnum'], axis=1)
# Out:
#              cicid   i94yr  i94mon  i94cit  i94res i94port  arrdate  i94mode  \
# 0              2.0  2016.0     3.0   213.0   213.0     XXX  20543.0      NaN
# 1              3.0  2016.0     3.0   245.0   245.0     XXX  20524.0      NaN
# 2              7.0  2016.0     3.0   260.0   260.0     SFR  20514.0      1.0
# 23           FL  20581.0   ...           O        O        M  1941.0
# 24           GA  20517.0   ...           G        O        M  1966.0
# 25           GA  20517.0   ...           G        O        M  1974.0
# 26           NC  20526.0   ...           O        O        M  1984.0
# 27           MA  20555.0   ...           G        O        M  1987.0
# 28           MA  20519.0   ...           O        O        M  1992.0
# 29           MD  20526.0   ...           G        O        M  1989.0
# ...         ...      ...   ...         ...      ...      ...     ...
# 3157042      PA  20534.0   ...           Z        K        M  1964.0
# 3157043     NaN  20540.0   ...           Z        K        M  1974.0
# 3157044     NaN  20594.0   ...           Z        O        M  1995.0
# 3157045     NaN  20579.0   ...           Z        O        M  1996.0
# 3157046      TN  20532.0   ...           Z        K        M  1971.0
# 3157047      ND  20518.0   ...           Z        K        M  1978.0
# 3157048      IN  20517.0   ...           Z        K        M  1973.0
# 3157049     NaN  20519.0   ...           Z        K        M  1999.0
# 3157050     NaN  20529.0   ...           Z        K        M  1943.0
# 3157051     NaN  20540.0   ...           Z        K        M  1984.0
# 3157052     NaN  20540.0   ...           Z        K        M  1986.0
# 3157053      IL  20541.0   ...           Z        K        M  1986.0
# 3157054      IL      NaN   ...           Z      NaN      NaN  1976.0
# 3157055     NaN  20522.0   ...           Z        O        M  1983.0
# 3157056     NaN      NaN   ...           Z      NaN      NaN  1973.0
# 3157057      CA  20562.0   ...           Z        I        M  1973.0
# 3157058      CA  20536.0   ...           Z        K        M  1978.0
# 3157059      CA  20524.0   ...           Z        O        M  1984.0
# 3157060      CA  20524.0   ...           Z        O        M  1984.0
# 3157061      CA  20516.0   ...           Z        O        M  1978.0
# 3157062      CA  20516.0   ...           Z        O        M  1982.0
# 3157063      CA  20586.0   ...           Z        O        M  1970.0
# 3157064      CA  20517.0   ...           Z        O        M  1964.0
# 3157065      CA  20526.0   ...           Z        O        M  1987.0
# 3157066      CA  20594.0   ...           Z        O        M  1993.0
# 3157067      VA  20532.0   ...           Z        K        M  1970.0
# 3157068      VA  20532.0   ...           Z        K        M  1971.0
# 3157069      VA  20532.0   ...           Z        K        M  2008.0
# 3157070      VA  20532.0   ...           Z        K        M  2004.0
# 3157071      MD  20541.0   ...           Z        K        M  1986.0
#
#           dtaddto gender airline        admnum  fltno visatype
# 0        09292016    NaN     NaN  1.140200e+09    NaN       B2
# 1        09102016    NaN     NaN  1.697295e+09    NaN       B2
# 2        08312016      F      PR  7.391007e+10  00104       B2
# 3             D/S      M     *GA  8.539319e+10  N900J       F1
# 4        08282016      M      AA  8.937570e+10     45       B1
# 5        08312016    NaN      TK  8.944788e+10  00003       B1
# 6        08312016      M      LH  8.946287e+10  00462       B2
# 7        08312016      M      VS  8.948222e+10  00009       B2
# 8        08312016      M      TK  8.948743e+10  00011       B2
# 9        08312016      M      TK  8.944831e+10  00003       B2
# 10       08312016      M      AZ  8.946067e+10  00608       B2
# 11       08312016      F      AZ  8.948165e+10  00610       B2
# 12       08312016      M      TK  8.948162e+10  00009       B2
# 13       08312016      F      LH  8.948435e+10  00434       B2
# 14       08312016      F      LH  8.948448e+10  00434       B2
# 15            D/S      F      BA  8.948039e+10  00049       F1
# 16            D/S      M      BA  8.948034e+10  00049       F1
# 17       08152016      M      EV  8.830011e+10  05318       B2
# 18       08152016      F      EV  8.830011e+10  05318       B2
# 19       08152016      F      EV  8.830011e+10  05318       B2
# 20       08152016      M      EV  8.830012e+10  05318       B2
# 21       05292016    NaN      DL  5.367617e+10  00075       WT
# 22       05292016    NaN      AF  5.366533e+10  00682       WT
# 23       05292016    NaN      AF  5.366533e+10  00682       WT
# 24       05292016      M      DL  5.366280e+10  00073       WB
# 25       05292016      M      DL  5.366302e+10  00073       WB
# 26       05292016    NaN      KL  5.368642e+10  00621       WT
# 27       05292016      M      WW  5.367463e+10  00125       WT
# 28       05292016    NaN      LH  5.365787e+10  00422       WB
# 29       05292016      M      BA  5.368085e+10  00229       WT
# ...           ...    ...     ...           ...    ...      ...
# 3157042  09192016      M     NaN  9.123957e+10   LAND       B1
# 3157043  07182016      F     NaN  8.591158e+10   LAND       B2
# 3157044       D/S      M     NaN  7.017846e+10  00099       F1
# 3157045       D/S      F     NaN  8.493189e+10  00137       F1
# 3157046  09112016      M     NaN  9.037904e+10   LAND       B1
# 3157047  08312016      M     NaN  8.946901e+10   LAND       B1
# 3157048  09022016      M     NaN  8.961074e+10   LAND       B1
# 3157049  05062016      F     NaN  7.871812e+10   LAND       B2
# 3157050  05252016      F     NaN  8.042312e+10   LAND       B2
# 3157051  06232016      M     NaN  8.320629e+10   LAND       B2
# 3157052  08122016      F     NaN  8.804345e+10   LAND       B2
# 3157053  09242016      M     NaN  9.181096e+10   LAND       B2
# 3157054  09242016      F     NaN  9.184267e+10   LAND       B2
# 3157055       D/S      F     NaN  4.991448e+10  00099       F1
# 3157056  07132016      M     NaN  8.543938e+10  00648       B2
# 3157057  09222016      F     NaN  9.162855e+10   LAND       B2
# 3157058  09042016      M     NaN  9.105977e+10   LAND       B1
# 3157059  08042016      M     NaN  8.743211e+10  00458       B1
# 3157060  08042016      M     NaN  8.743224e+10  00458       B1
# 3157061  08172016      M     NaN  8.850298e+10  00066       B1
# 3157062  08172016      M     NaN  8.850310e+10  00066       B1
# 3157063  08222016      M     NaN  8.889726e+10  00163       B2
# 3157064  08262016      F     NaN  8.921911e+10  00015       B2
# 3157065  08262016    NaN     NaN  8.922570e+10  00641       B2
# 3157066       D/S      F     NaN  8.580949e+10  00088       F1
# 3157067  09112016      M     NaN  9.038337e+10   LAND       B2
# 3157068  09112016      F     NaN  9.038355e+10   LAND       B2
# 3157069  09112016      F     NaN  9.038359e+10   LAND       B2
# 3157070  09112016      M     NaN  9.038366e+10   LAND       B2
# 3157071  09242016      F     NaN  9.179781e+10   LAND       B2
#
# [3157072 rows x 25 columns]

# %%
x_df = df[df['i94port'] == 'XXX']
x_df.shape
# Out:
# (1725, 28)
